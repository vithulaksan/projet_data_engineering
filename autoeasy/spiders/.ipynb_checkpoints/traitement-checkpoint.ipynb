# %%
import pandas as pd

# %%
lire = pd.read_json("vithu.json")

# %%
lire
# Out:
#                                                    Nom       Marque  \
# 0    PEUGEOT PARTNER TEPEE 1.6 e-HDi S&S 92 cv  ZENITH     PEUGEOT
# 1        VOLKSWAGEN GOLF SW VII 1.0 TSI 110 ch CONNECT  VOLKSWAGEN
# 2              RENAULT KOLEOS 2.0 dCi 175 INITIALE BVA     RENAULT
# 3      AUDI S3 SPORTBACK 2.0 TFSI 300 QUATTRO S-TRONIC        AUDI
# 4     CITROEN C3 1.2 THP PURETECH EAT6 S&S 110 ORIGINS     CITROEN
# ..                                                 ...          ...
# 839  FORD RANGER 3.2 TDCi 200ch Double Cabine Wildt...        FORD
# 840                        AUDI A3 1.2 TFSI 110 S LINE        AUDI
# 841      FORD COURRIER 1.5l TD 95 CH TRANSIT COURRIER         FORD
# 842  NISSAN X-TRAIL PHASE 2 1.6 DCI 130 CH N-CONNECTA       NISSAN
# 843  MERCEDES CLASSE C 220 CDI 170 AVANTGARDE 13250...    MERCEDES
#
#                     Modèle Mise en circulation Kilométrage  Énergie  \
# 0    PEUGEOT PARTNER TEPEE          05/05/2014   185000 km   DIESEL
# 1          VOLKSWAGEN GOLF          12/06/2018    53448 km  ESSENCE
# 2           RENAULT KOLEOS          27/05/2014   154500 km   DIESEL
# 3                  AUDI S3          16/01/2015   143000 km  ESSENCE
# 4               CITROEN C3          12/04/2019    46000 km  ESSENCE
# ..                     ...                 ...         ...      ...
# 839            FORD RANGER          05/01/2016   114000 km   DIESEL
# 840                AUDI A3          01/02/2015   120500 km  ESSENCE
# 841          FORD COURRIER          30/04/2018    53500 km   DIESEL
# 842         NISSAN X-TRAIL          31/10/2017    79000 km   DIESEL
# 843      MERCEDES CLASSE C          13/07/2011   132500 km   DIESEL
#
#     Boite de vitesse Puissance fiscale Garantie Emission de CO2      Prix
# 0           MANUELLE              5 Ch   6 MOIS         123g/km   7 990 €
# 1           MANUELLE              6 Ch   6 MOIS         112g/km  16 990 €
# 2        AUTOMATIQUE             10 Ch   6 MOIS         175g/km   9 990 €
# 3        AUTOMATIQUE             19 Ch  12 MOIS         159g/km  25 990 €
# 4        AUTOMATIQUE              6 Ch  12 MOIS         114g/km  13 990 €
# ..               ...               ...      ...             ...       ...
# 839      AUTOMATIQUE             11 Ch   6 MOIS         265g/km  25 990 €
# 840         MANUELLE               N.C      NaN         133g/km  12 490 €
# 841         MANUELLE              6 Ch   3 MOIS         104g/km  11 990 €
# 842         MANUELLE              7 Ch   3 MOIS         133g/km  18 990 €
# 843      AUTOMATIQUE              9 Ch   6 MOIS         131g/km  12 490 €
#
# [844 rows x 11 columns]

# %%
lire.rename(columns={'Kilométrage': 'Kilométrage (en km)', 
                    'Puissance fiscale': 'Puissance fiscale (en Ch)',
                     'Garantie':'Garantie (en mois)',
                     'Emission de CO2':'Emission de CO2 (en g/km)',
                    'Prix': 'Prix (en €)'}, inplace=True)

# %%
print(lire.columns)
# Out:
# Index(['Nom', 'Marque', 'Modèle', 'Mise en circulation', 'Kilométrage',
#        'Énergie', 'Boite de vitesse', 'Puissance fiscale', 'Garantie',
#        'Emission de CO2', 'Prix'],
#       dtype='object')

# %%
lire.dtypes
# Out:
# Nom                    object
# Marque                 object
# Modèle                 object
# Mise en circulation    object
# Kilométrage            object
# Énergie                object
# Boite de vitesse       object
# Puissance fiscale      object
# Garantie               object
# Emission de CO2        object
# Prix                   object
# dtype: object
